# %%
#import collection
import rasterio
import os
from pprint import pprint

from rasterio.vrt import WarpedVRT
from rasterio import transform

from matplotlib import pyplot

import re

# %% [markdown]
# Seed set to 42 to ensure ease of replication.

# %%
random_seed = 42

# %% [markdown]
# Get data from NAS. Currently having to get data manually.

# %%
def load_data_from_nas():
    return

# %% [markdown]
# Useful Functions:

# %%
def create_test_set_from_sample_data(seed):
    return

def get_gis_raster_array_from_file(path):
    with rasterio.open(path) as input_data:
        raster_array = input_data.read(1)
        return raster_array

def print_raster_array(raster_array):
    pyplot.imshow(raster_array, cmap='pink')
    pyplot.show()

def get_scenario_directory_path(scenario_name):
    cwd = os.getcwd()
    data_folder_path = "data/Unpartitioned  Data  - Do Not Open Files/NAS Contents/RGW_ClimFire/LandisOutputs/C"
    scenario_directory = os.path.join(cwd, data_folder_path, scenario_name)
    return scenario_directory

def get_input_files_by_scenario_and_replication(scenario_name, replication_number):
    scenario_directory = get_scenario_directory_path(scenario_name)
    input_folder = os.path.join(scenario_directory, "fire")
    pattern = re.compile(r"^severity-\d+\.img$")

# %%
sample_file_folder = "/home/user/Projects/good-fire-ml/data/Unpartitioned  Data  - Do Not Open Files/NAS Contents/RGW_ClimFire/LandisOutputs/CESM1BGC_100yrs_withfires_Scen/replicate1"
input_folder = os.path.join(sample_file_folder, "fire")
input_file = os.path.join(input_folder, "severity-1.img")

raster_array = get_gis_raster_array_from_file(input_file)
print_raster_array(raster_array)
# Out:
# /tmp/ipykernel_297442/3751356262.py:6: DeprecationWarning: Setting the shape on a NumPy array has been deprecated in NumPy 2.5.
# As an alternative, you can create a new view using np.reshape (with copy=False if needed).
#   raster_array = input_data.read(1)
